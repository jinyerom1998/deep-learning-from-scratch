# %% [markdown]
# # 1장 - 헬로 파이썬

# %% [markdown]
# ### 산술 연산

# %%
1 - 2
# Out:
# -1

# %%
4 * 5
# Out:
# 20

# %%
7 / 5
# Out:
# 1.4

# %%
3 ** 2
# Out:
# 9

# %% [markdown]
# ### 자료형

# %%
type(10)
# Out:
# int

# %%
type(2.718)
# Out:
# float

# %%
type("hello")
# Out:
# str

# %% [markdown]
# ### 변수
# 파이썬은 **동적 언어**이므로 변수의 자료형을 상황에 맞게 자동으로 결정한다.
# 그 예로 아래와 같은 상황을 들 수 있다.

# %%
x = 10
print(x)
# Out:
# 10

# %%
x = 100
print(x)
# Out:
# 100

# %%
y = 3.14
x * y # 정수와 실수를 곱한 결과 자동 형변환이 이루어져 실수가 된다.
# Out:
# 314.0

# %%
type(x * y)
# Out:
# float

# %% [markdown]
# ### 리스트
# 인덱싱과 슬라이싱이 특징이다.

# %%
a = [1, 2, 3, 4, 5] # 리스크 생성
print(a) # 출력
# Out:
# [1, 2, 3, 4, 5]

# %%
len(a) # 리스트의 길이 출력
# Out:
# 5

# %%
a[0] # 첫 번째 원소에 접근
# Out:
# 1

# %%
a[4] # 다섯 번째 원소에 접근
# Out:
# 5

# %%
a[4] = 99 # 값 대입
print(a)
# Out:
# [1, 2, 3, 4, 99]

# %%
print(a)
# Out:
# [1, 2, 3, 4, 99]

# %%
a[0:2]
# Out:
# [1, 2]

# %%
a[1:]
# Out:
# [2, 3, 4, 99]

# %%
a[:3]
# Out:
# [1, 2, 3]

# %%
a[:-1]
# Out:
# [1, 2, 3, 4]

# %%
a[:-2]
# Out:
# [1, 2, 3]

# %% [markdown]
# ### 딕셔너리
# **키: 값**의 한 쌍으로 이루어진다.

# %%
me = {'height':180} # 딕셔너리 생성
me['height'] # 원소에 접근
# Out:
# 180

# %%
me['weight'] = 70 # 새 원소 추가
print(me)
# Out:
# {'height': 180, 'weight': 70}

# %% [markdown]
# ### bool 자료형
# True / False 둘 중 하나를 값으로 취한다.
# and, or, not 연산자를 사용할 수 있다.

# %%
hungry = True
sleepy = False

# %%
type(hungry)
# Out:
# bool

# %%
not hungry
# Out:
# False

# %%
hungry and sleepy
# Out:
# False

# %%
hungry or sleepy
# Out:
# True

# %% [markdown]
# ### if 문
# 조건에 따라서 달리 처리하려면 if/else 문을 사용한다.

# %%
hungry = True
if hungry:
    print("I'm hungry")
# Out:
# I'm hungry

# %%
hungry = False
if hungry:
    print("I'm hungry")
else:
    print("I'm not hungry")
    print("I'm sleepy")
# Out:
# I'm not hungry
# I'm sleepy

# %% [markdown]
# ### for 문
# 반복(루프) 처리에는 for 문을 사용한다.

# %%
for i in[1, 2, 3]:
    print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# ### 함수
# 특정 기능을 수행하는 일련의 명령들을 묶어 하나의 함수로 정의할 수 있다.

# %%
def hello():
    print("Hello World!")

hello()
# Out:
# Hello World!

# %%
def hello(object):
    print("Hello " + object + "!")

hello("cat")
# Out:
# Hello cat!

# %% [markdown]
# ### 클래스
# 개발자가 직접 클래스를 정의하면 독자적인 자료형 만들기가 가능하다.

# %%
class 클래스 이름:
    def __init__(self, 인수, ...):
        # init 메서드: 클래스를 초기화하는 방법을 정의한다.
        # 초기화용 메서드, 생성자라고도 한다.
        # 클래스의 인스턴스가 만들어질 때 한번만 불린다.

    def 메서드 이름 1(self, 인수, ...):
    

    def 메서드 이름 2(self, 인수, ...):
# Out:
#   Cell In[100], line 1
#     class 클래스 이름:
#               ^
# SyntaxError: invalid syntax

# %%
class Man:
    def __init__(self, name):
        self.name = name # Man의 생성자는 name이라는 인수를 받고, 그 인수로 인스턴스 변수인 self.name을 초기화한다.
        # 인스턴스 변수는 인스턴스별로 저장되는 변수이다.
        # 파이썬에서는 self.name처럼 self 다음에 속성 이름을 써서 인스턴스 변수를 작성하거나 접근할 수 있다.
        print("Initialized!")

    def hello(self):
        print("Hello " + self.name + "!")

    def goodbye(self):
        print("Good-bye " + self.name + "!")

m = Man("David") # m이라는 인스턴스(객체)를 생성한다.
m.hello()
m.goodbye()
# Out:
# Initialized!
# Hello David!
# Good-bye David!

# %% [markdown]
# ### 넘파이

# %%
import numpy as np

# %%
# 넘파이 배열을 만들 때는 np.array() 메서드를 이용한다.
# np.array()는 파이썬의 리스트를 인수로 받아 넘파이 라이브러리가 제공하는 특수한 형태의 배열(numpy.ndarray)을 반환한다.

x = np.array([1.0, 2.0, 3.0])
print(x)
# Out:
# [1. 2. 3.]

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x = np.array([1.0, 2.0, 3.0])
y = np.array([2.0, 4.0, 6.0])

x + y
# Out:
# array([3., 6., 9.])

# %%
x - y
# Out:
# array([-1., -2., -3.])

# %%
x * y
# Out:
# array([ 2.,  8., 18.])

# %%
x / y
# Out:
# array([0.5, 0.5, 0.5])

# %%
x = np.array([1.0, 2.0, 3.0])
x / 2.0
# Out:
# array([0.5, 1. , 1.5])

# %% [markdown]
# ### 넘파이의 N차원 배열

# %%
A = np.array([[1, 2], [3, 4]])
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A.shape
# Out:
# (2, 2)

# %%
A.dtype
# Out:
# dtype('int32')

# %%
B = np.array([[3, 0], [0, 6]])

A + B
# Out:
# array([[ 4,  2],
#        [ 3, 10]])

# %%
A * B
# Out:
# array([[ 3,  0],
#        [ 0, 24]])

# %%
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
A * 10 # 브로드캐스트 기능이 적용되었다.
# 넘파이 배열과 수치 하나(스칼라값)의 조합으로 된 산술 연산의 수행이다.
# Out:
# array([[10, 20],
#        [30, 40]])

# %% [markdown]
# ### 브로드캐스트

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([10, 20])

A * B
# Out:
# array([[10, 40],
#        [30, 80]])

# %% [markdown]
# ### 원소 접근

# %%
X = np.array([[51, 55], [14, 19], [0, 4]])
print(X)
# Out:
# [[51 55]
#  [14 19]
#  [ 0  4]]

# %%
X[0]
# Out:
# array([51, 55])

# %%
X[0][1]
# Out:
# 55

# %%
for row in X:
    print(row)
# Out:
# [51 55]
# [14 19]
# [0 4]

# %%
X = X.flatten() # X를 1차원 배열로 변환(평탄화)
print(X)
# Out:
# [51 55 14 19  0  4]

# %%
X[np.array([0, 2, 4])] # 인덱스가 0, 2, 4인 원소 얻기
# Out:
# array([51, 14,  0])

# %%
X > 15
# Out:
# array([ True,  True, False,  True, False, False])

# %%
X[X>15]
# Out:
# array([51, 55, 19])

# %% [markdown]
# ### matplotlib
# 그래프를 그려주는 라이브러리이다.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0, 6, 0.1) # 0에서 6까지 0.1 간격으로 생성
y = np.sin(x)

# 그래프 그리기
plt.plot(x, y)
plt.show()

# %% [markdown]
# ### pyplot의 기능

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0, 6, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

# 그래프 그리기
plt.plot(x, y1, label="sin")
plt.plot(x, y2, linestyle="--", label="cos")
plt.xlabel("x")
plt.ylabel("y")
plt.title('sin & cos')
plt.legend()
plt.show()

# %% [markdown]
# ### 이미지 표시하기

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('./그림자료들/lena.jpg') # 이미지 읽어오기

plt.imshow(img)
plt.show()
